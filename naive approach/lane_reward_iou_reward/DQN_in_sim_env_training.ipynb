# %% [markdown]
# # REQ

# %%
#learninmg rate decay rate 0.01 500 step 
decay_steps=100
deacy_rate=0.001
#learning rate 
#lr=0.001
learning_rate=0.001

# %%
import math, random
#import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)
#?

# %%
from collections import deque
class ReplayBuffer(object):
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        state      = np.expand_dims(state, 0)
        next_state = np.expand_dims(next_state, 0)
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        return np.concatenate(state), action, reward, np.concatenate(next_state), done
    
    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # env

# %%
import pickle
import numpy as np
import cv2

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/Projects /rl_pro'
# Out:
# /content/gdrive/My Drive/Projects /rl_pro

# %%
class sim_env:
  '''
  total frames 980 
  980/4=245 frames 
  why dont u try frame skip only 4 frames per second 
  so 32 second / 32 step game 
  30 frames => you wanna select 4 => frame 1 , frame 10 , frame 20 , frame 30 
  skip 10 frames 
  so 24 steps 
  1+40*24=961
  if num>950 then done 
  '''
  def __init__(self,bouding_box_list):

        self.lane_data_file_name="lane_coordinates_t3_mp4.txt"

        self.iou_sacle_factor=50;
        self.scale_factor_lane=-1
        self.frame_skip_step=10
        #self.video_file_path = video_file_path
        self.bouding_box_list = bouding_box_list
        self.frame_num=0
        #initial coord of car 
        self.x1=580
        self.x2=717
        self.y2=700
        self.y1=600
        self.step_size=20
        #how many pixel car moves if action L or R is taken 
        #height and width of input video file image 
        self.height=720
        self.width=1280
        self.classes_to_consider=['Car','Person','Land vehicle','Vehicle','Van','Truck']
        
        
        #load from txt file the bouding boxes corresponding to each frame 
        with open(bouding_box_list, "rb") as fp:
          self.box_file=pickle.load(fp)

        #load lane data from text file 
        with open(self.lane_data_file_name, "rb") as fp: 
          self.lane_file = pickle.load(fp)
        
  def reset(self):
    self.frame_num=0
    self.x1=580
    self.x2=717
    self.y2=700
    self.y1=600
    return self.return_frame_stack(self.frame_num)

  def return_frame_stack(self,num):
    frame1=self.return_frame(num)
    frame2=self.return_frame(num+self.frame_skip_step)
    frame3=self.return_frame(num+2*self.frame_skip_step)
    frame4=self.return_frame(num+3*self.frame_skip_step)
    frame_stack=np.stack((frame1,frame2,frame3,frame4),axis=0)

    #state=torch.from_numpy(frame_stack)
    #state=state.unsqueeze(0)
    #state=state.float()
    #return state
    return frame_stack

  def return_total_iou(self,num):
    iou1=self.return_iou(num)
    iou2=self.return_iou(num+self.frame_skip_step)
    iou3=self.return_iou(num+2*self.frame_skip_step)
    iou4=self.return_iou(num+3*self.frame_skip_step)
    iou_total=iou1+iou2+iou3+iou4
    return iou_total

  def return_frame(self,num):
    '''
    make a blank image of correct dimension height and width
    read file and get coord of cars 
    fill the blank image with bouding boxes of cars 
    retun the image   
    '''
    height=self.height
    width=self.width
    result_of_object_det=self.box_file[num]
    boxes=result_of_object_det["detection_boxes"]
    class_names=result_of_object_det["detection_class_entities"]
    scores=result_of_object_det["detection_scores"]
    num_of_detetected_objects=boxes.shape[0]
    blank_img=np.zeros(shape=[height,width], dtype=np.uint8)
    #draw_our_car
    blank_img=cv2.rectangle(blank_img,(self.x1,self.y1),(self.x2,self.y2),(255,0,0),-1)
    
    #total_iou=0
    for i in range (0,num_of_detetected_objects):
      det_score=scores[i].numpy()
      threshold=0.1
      if(det_score>threshold):
            class_name=class_names[i].numpy()
            class_name=str(class_name, 'UTF-8')
            if class_name in self.classes_to_consider:
                    box=boxes[i].numpy()
                    ymin=int(box[0]*height)
                    xmin=int(box[1]*width)
                    ymax=int(box[2]*height)
                    xmax=int(box[3]*width)
                    blank_img=cv2.rectangle(blank_img,(xmin,ymin),(xmax,ymax),(255,0,0),-1)
                    #iou cal 
                    #iou_of_curr_box=self.get_iou([xmin,ymin,xmax,ymax])
                    #total_iou=total_iou + self.iou_sacle_factor*iou_of_curr_box
    return blank_img

  def return_iou(self,num):
      '''
      make a blank image of correct dimension height and width
      read file and get coord of cars 
      fill the blank image with bouding boxes of cars 
      retun the image   
      '''
      height=self.height
      width=self.width
      result_of_object_det=self.box_file[num]
      boxes=result_of_object_det["detection_boxes"]
      class_names=result_of_object_det["detection_class_entities"]
      scores=result_of_object_det["detection_scores"]
      num_of_detetected_objects=boxes.shape[0]
      #blank_img=np.zeros(shape=[height,width], dtype=np.uint8)
      #draw_our_car
      #blank_img=cv2.rectangle(blank_img,(self.x1,self.y1),(self.x2,self.y2),(255,0,0),-1)
      total_iou=0
      for i in range (0,num_of_detetected_objects):
        det_score=scores[i].numpy()
        threshold=0.1
        if(det_score>threshold):
              class_name=class_names[i].numpy()
              class_name=str(class_name, 'UTF-8')
              if class_name in self.classes_to_consider:
                      box=boxes[i].numpy()
                      ymin=int(box[0]*height)
                      xmin=int(box[1]*width)
                      ymax=int(box[2]*height)
                      xmax=int(box[3]*width)
                      #blank_img=cv2.rectangle(blank_img,(xmin,ymin),(xmax,ymax),(255,0,0),-1)
                      #iou cal 
                      iou_of_curr_box=self.get_iou([xmin,ymin,xmax,ymax])
                      total_iou=total_iou + self.iou_sacle_factor*iou_of_curr_box
      return total_iou

  def act(self,action_num):
    '''
    0=> move Left self.step_size=20 
    1=> no acton remain in position 
    2=> Right self.step_size=20
    '''
    if action_num==0:
      self.x1=self.x1-20
      self.x2=self.x2-20
    elif action_num==2:
      self.x1=self.x1+20
      self.x2=self.x2+20

  def step(self,action_num):
    '''
    take action
    cal iou for prev frame stack 
    return next frame stack
    
    '''
    #frame_num
    #return next_state,reward,done
    #def get_orginal_frame(self,frame_num):
    
    '''
    1 executre action
    2 calculate reward
    3 update frame num 
    4 check done or not 
    5 fetch next set of frames 
    '''
    done=0
    self.act(action_num) #executre action
    total_iou=self.return_total_iou(self.frame_num) #calculate reward

  
    #print("iou reward=",-1*total_iou)
    #print("lane Reward = ",self.lane_rwd() )


    reward=-1*total_iou + self.lane_rwd()

    self.frame_num=self.frame_num+40 #update frame num

    next_set_frame_num=self.frame_num+40#check done or not 
    next_state=None
    if(next_set_frame_num>980):
      done=1
      next_state= self.return_frame_stack(0)#just for the reply buffer wont be used during training coz (1-done)*next_state_q_values 
    else :
      next_state= self.return_frame_stack(self.frame_num)#fetch next frame stack 
    return next_state,reward,done

  def get_iou(self,box):

      bb1={}
      bb2={}
      bb1['x1']=self.x1
      bb1['y1']=self.y1
      bb1['x2']=self.x2
      bb1['y2']=self.y2

      bb2['x1']=box[0]
      bb2['y1']=box[1]
      bb2['x2']=box[2]
      bb2['y2']=box[3]
      #print(bb2)
      assert bb1['x1'] < bb1['x2']
      assert bb1['y1'] < bb1['y2']
      assert bb2['x1'] < bb2['x2']
      assert bb2['y1'] < bb2['y2']

      x_left = max(bb1['x1'], bb2['x1'])
      y_top = max(bb1['y1'], bb2['y1'])
      x_right = min(bb1['x2'], bb2['x2'])
      y_bottom = min(bb1['y2'], bb2['y2'])

      if x_right < x_left or y_bottom < y_top:
          return 0.0
    
      # The intersection of two axis-aligned bounding boxes is always an
      # axis-aligned bounding box
      intersection_area = (x_right - x_left) * (y_bottom - y_top)
      # compute the area of both AABBs
      bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
      bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

      # compute the intersection over union by taking the intersection
      # area and dividing it by the sum of prediction + ground-truth
      # areas - the interesection area
      iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
      assert iou >= 0.0
      assert iou <= 1.0
      return iou


  def lane_rwd(self):
    x_pos_of_car=(self.x1+self.x2)/2
    mid_points=self.get_mid_point_of_lanes(self.split_lanes())
    dist=[] 
    for mid_x in  mid_points:
      if(x_pos_of_car>mid_x):
        d=x_pos_of_car-mid_x
      else:
        d=mid_x-x_pos_of_car
        dist.append(d)
    dist.sort()
    if(len(dist)!=0):
      lane_reward=self.scale_factor_lane*dist[0]
    else :
      lane_reward=0

    return lane_reward 

  def split_lanes(self):
    lane_data=self.lane_file[self.frame_num]
    individual_lanes=[]
    lane_1=[]
    lane_1.append(lane_data[0])
    for i in range (1,len(lane_data)):
      if(lane_data[i][1]==716):
        individual_lanes.append(lane_1)
        lane_1=[]
        lane_1.append(lane_data[i])
      else :
        lane_1.append(lane_data[i])  
    individual_lanes.append(lane_1)
    return individual_lanes

  def get_mid_point_of_lanes(self,individual_lanes):
    l=len(individual_lanes)
    mid_points=[]
    for i in range(0,l-1):
      lane_a=individual_lanes[i]
      lane_b=individual_lanes[i+1]
      temp=(lane_a[0][0]+lane_b[0][0])/2
      mid_points.append(temp)
    return mid_points

# %%
      #split lanes 
      
      
      #get mid point of lane 
      
        #find closest mid point and estimate reward
        
        #if lane_reward==None:
        # lane_reward=0

# %%
import random
env=sim_env("obj_det_result_t3.txt")

# %%
ls
# Out:
#  action_frame_map.txt          od_t3.mp4
# 'download (3).png'             orginal_video_with_lane_markings.mp4
#  lane_coordinates_t3_mp4.txt   t3.mp4
#  model_param                   x.txt
#  obj_det_result_t3.txt

# %%
#env_id = "CartPole-v0"
#env = gym.make(env_id)

# %% [markdown]
# # training

# %%
epsilon_start = 1.0
epsilon_final = 0.01
epsilon_decay = 500

epsilon_by_frame = lambda frame_idx: epsilon_final + (epsilon_start - epsilon_final) * math.exp(-1. * frame_idx / epsilon_decay)

# %%
plt.plot([epsilon_by_frame(i) for i in range(1000)])

# %%
class DQN(nn.Module):
    def __init__(self,num_ch, num_actions):
        super(DQN, self).__init__()
        
        self.block1 = nn.Sequential(
            nn.Conv2d( num_ch,8, kernel_size=3, stride=2, padding=0),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d( 8,16, kernel_size=3, stride=2, padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
            )

        self.block2= nn.Sequential(
            nn.Linear(55616, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, num_actions)
            )
        
    def forward(self, x):
        x=self.block1(x)
        x = x.view(x.size(0), -1)#flatten
        x=self.block2(x)
        return x
        
    
    def act(self, state, epsilon):
        #print("ACTTT ")
        if random.random() > epsilon:
            state   = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
            q_value = self.forward(state)
            action  = q_value.max(1)[1].data[0]
            action=action.item()

            #print("state=:",state,"q_value=",q_value,"action=",action)

            #print("action from above")
        else:
            action = random.randrange(3)
            #print("action from below")
        return action

# %% [markdown]
# # New Section

# %%
model = DQN(4,3)
if USE_CUDA:
    model = model.cuda()
    
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=decay_steps, gamma=deacy_rate)
replay_buffer = ReplayBuffer(1000)

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size)
    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = Variable(torch.FloatTensor(reward))
    done       = Variable(torch.FloatTensor(done))

    q_values      = model(state)
    next_q_values = model(next_state)

    q_value          = q_values.gather(1, action.unsqueeze(1)).squeeze(1)
    next_q_value     = next_q_values.max(1)[0]
    expected_q_value = reward + gamma * next_q_value * (1 - done)
    
    loss = (q_value - Variable(expected_q_value.data)).pow(2).mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #scheduler.step()
    
    return loss

# %%
def plot(frame_idx, rewards, losses):
    clear_output(True)
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('frame %s. reward: %s' % (frame_idx, np.mean(rewards[-10:])))
    plt.plot(rewards)
    plt.subplot(132)
    plt.title('loss')
    plt.plot(losses)
    plt.show()

# %%
#state=env.reset()

# %%
#print(state.shape)

# %%
num_frames = 10000
batch_size = 32
gamma      = 0.99

losses = []
all_rewards = []
episode_reward = 0

state = env.reset()
for frame_idx in range(1, num_frames + 1):
    epsilon = epsilon_by_frame(frame_idx)
    #state=torch.from_numpy(state)
    #state=state.unsqueeze(0)
    #state=state.float()

    #print(state.shape)
    #print(done)
    #print(state.shape)
    
    action = model.act(state, epsilon)
    #print(action)
    next_state, reward, done = env.step(action)
    #print(next_state.shape)
    replay_buffer.push(state.squeeze(), action, reward, next_state, done)
    
    state = next_state
    episode_reward += reward
    
    if done:
        state = env.reset()
        all_rewards.append(episode_reward)
        episode_reward = 0
        
    if len(replay_buffer) > batch_size:
        loss = compute_td_loss(batch_size)
        #print(loss.item())
        #losses.append(loss.data[0])
        losses.append(loss.item())
        
    if frame_idx % 10 == 0:
        plot(frame_idx, all_rewards, losses)

# %%
'''
saving model
torch.save(model.state_dict(), PATH)
model = TheModelClass(*args, **kwargs)
model.load_state_dict(torch.load(PATH))
model.eval()
'''

# %%
ls
# Out:
#  action_frame_map.txt          new_model_param                        t3.mp4
# 'download (3).png'             obj_det_result_t3.txt                  x.txt
#  lane_coordinates_t3_mp4.txt   od_t3.mp4
#  model_param                   orginal_video_with_lane_markings.mp4

# %%
torch.save(model.state_dict(),"new_model_param")

# %%
model_s = DQN(4,3)

# %%
model_s.load_state_dict(torch.load("model_param"))
model_s.eval()
# Out:
# DQN(
#   (block1): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): Sequential(
#     (0): Linear(in_features=55616, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# # run env for 10 times with trained model

# %%
state=env.reset()
r=0
reward_list=[]
i=0
while(1):

  action = model.act(state, epsilon)
  #print(action)
  next_state, reward, done = env.step(action)
  state=next_state
  r=reward+r
  if done==1:
    state=env.reset()
    reward_list.append(r)
    print("i=",i,"r=",r)
    r=0
    i=i+1

  if i>10:
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# i= 0 r= 0.0
# i= 1 r= -0.02926469575409644
# i= 2 r= -4.9818406117809335
# i= 3 r= 0.0
# i= 4 r= 0.0
# i= 5 r= 0.0
# i= 6 r= 0.0
# i= 7 r= 0.0
# i= 8 r= 0.0
# i= 9 r= -8.507203883245934
# i= 10 r= 0.0

# %% [markdown]
# # Run env 10 times with random action

# %%
import random

# %%
state=env.reset()
r=0
reward_list=[]
i=0
action_list = [0,1,2]


while(1):
  action=random.choice(action_list)
  #print(action)
  next_state, reward, done = env.step(action)
  state=next_state
  r=reward+r
  if done==1:
    state=env.reset()
    reward_list.append(r)
    print("i=",i,"r=",r)
    r=0
    i=i+1

  if i>10:
    break
# Out:
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -355.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -396.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -330.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -318.5
# helllo bois
# iou reward= -0.45714460295389525
# lane Reward =  -337.5
# helllo bois
# iou reward= -3.326212220002248
# lane Reward =  0
# helllo bois
# iou reward= -0.47553305721736466
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.16122689736531656
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# i= 0 r= -1741.9201167775389
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -2.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -17.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -14.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -32.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -35.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -3.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -9.0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -5.9426405053258495
# lane Reward =  0
# helllo bois
# iou reward= -18.06690965940658
# lane Reward =  0
# helllo bois
# iou reward= -30.268791026208422
# lane Reward =  0
# i= 1 r= -190.27834119094084
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -42.0
# helllo bois
# iou reward= -0.7007299270072992
# lane Reward =  -77.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -34.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -52.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -55.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -0.1624292328148973
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -27.5
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -19.5
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -9.138093719878981
# lane Reward =  0
# helllo bois
# iou reward= -22.24456807092276
# lane Reward =  0
# helllo bois
# iou reward= -45.310328893449096
# lane Reward =  0
# i= 2 r= -460.556149844073
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -2.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -17.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -350.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -338.5
# helllo bois
# iou reward= -0.8881542719433189
# lane Reward =  -317.5
# helllo bois
# iou reward= -3.326212220002248
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -9.138093719878981
# lane Reward =  0
# helllo bois
# iou reward= -26.086864419334585
# lane Reward =  0
# helllo bois
# iou reward= -46.418198650610776
# lane Reward =  0
# i= 3 r= -1110.8575232817698
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -2.0
# helllo bois
# iou reward= -0.6120664529291752
# lane Reward =  -37.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -14.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -12.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -35.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -3.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -1.213278661440999
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -27.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -18.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -13.0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -2.8007133760425558
# lane Reward =  0
# helllo bois
# iou reward= -6.462389500429021
# lane Reward =  0
# helllo bois
# iou reward= -16.54330164245469
# lane Reward =  0
# i= 4 r= -242.13174963329644
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -2.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -396.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -350.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -378.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -15.0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -3.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -7.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -18.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -33.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -38.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -59.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -56.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -60.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -66.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -95.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -92.5
# helllo bois
# iou reward= -3.1092934937337335
# lane Reward =  -59.5
# helllo bois
# iou reward= -4.524517449417171
# lane Reward =  -25.5
# helllo bois
# iou reward= -18.683885623766358
# lane Reward =  -9.5
# helllo bois
# iou reward= -31.13348790841666
# lane Reward =  -38.5
# i= 5 r= -1891.4511844753338
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -22.0
# helllo bois
# iou reward= -0.6120664529291752
# lane Reward =  -37.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -34.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -52.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -35.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -3.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -0.1624292328148973
# lane Reward =  0
# helllo bois
# iou reward= -1.2864770475492988
# lane Reward =  -47.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -58.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -73.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -38.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -79.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -96.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -60.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -86.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -115.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -72.5
# helllo bois
# iou reward= -1.1048142517027457
# lane Reward =  -39.5
# helllo bois
# iou reward= -3.314191939571707
# lane Reward =  -45.5
# helllo bois
# iou reward= -8.561779665909583
# lane Reward =  -69.5
# helllo bois
# iou reward= -19.74766875653735
# lane Reward =  -78.5
# i= 6 r= -1230.289427347015
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -42.0
# helllo bois
# iou reward= -0.6120664529291752
# lane Reward =  -37.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -14.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -32.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -55.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -3.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -0.1624292328148973
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -27.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -18.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -13.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -18.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -19.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -36.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -40.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -66.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -95.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -52.5
# helllo bois
# iou reward= -3.1092934937337335
# lane Reward =  -59.5
# helllo bois
# iou reward= -3.890872126040807
# lane Reward =  -65.5
# helllo bois
# iou reward= -8.561779665909583
# lane Reward =  -69.5
# helllo bois
# iou reward= -14.666495420851202
# lane Reward =  -98.5
# i= 7 r= -946.5029363922795
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -42.0
# helllo bois
# iou reward= -0.7007299270072992
# lane Reward =  -57.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -54.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -32.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -55.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -23.5
# helllo bois
# iou reward= -0.04011461318051576
# lane Reward =  -43.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -29.0
# helllo bois
# iou reward= -1.213278661440999
# lane Reward =  0
# helllo bois
# iou reward= -3.0430465118684578
# lane Reward =  -67.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -78.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -53.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -18.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -39.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -56.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -60.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -46.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -95.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -92.5
# helllo bois
# iou reward= -3.1092934937337335
# lane Reward =  -59.5
# helllo bois
# iou reward= -3.314191939571707
# lane Reward =  -45.5
# helllo bois
# iou reward= -11.788653102395692
# lane Reward =  -49.5
# helllo bois
# iou reward= -19.74766875653735
# lane Reward =  -78.5
# i= 8 r= -1218.4569770057358
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -355.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -376.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -350.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -338.5
# helllo bois
# iou reward= -0.45714460295389525
# lane Reward =  -337.5
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -6.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -15.5
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -7.715222715921664
# lane Reward =  0
# helllo bois
# iou reward= -26.030976729987856
# lane Reward =  0
# helllo bois
# iou reward= -46.418198650610776
# lane Reward =  0
# i= 9 r= -1859.6215426994743
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  -2.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -396.5
# helllo bois
# iou reward= -0.0
# lane Reward =  -330.0
# helllo bois
# iou reward= -0.0
# lane Reward =  -318.5
# helllo bois
# iou reward= -0.45714460295389525
# lane Reward =  -337.5
# helllo bois
# iou reward= -0.8796091139077354
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -0.0
# lane Reward =  0
# helllo bois
# iou reward= -5.9426405053258495
# lane Reward =  0
# helllo bois
# iou reward= -14.05017681421856
# lane Reward =  0
# helllo bois
# iou reward= -37.80992643603618
# lane Reward =  0
# i= 10 r= -1443.6394974724424
