# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content'

# %%
cd '/content/gdrive/My Drive/Projects /RL_Driving/Drone_view'
# Out:
# /content/gdrive/My Drive/Projects /RL_Driving/Drone_view

# %%
cd '/content/gdrive/My Drive/Projects /RL_Driving/Front_view'
# Out:
# /content/gdrive/My Drive/Projects /RL_Driving/Front_view

# %%
ls
# Out:
# final_60ae52e07c16e9007c4ca144_50027.mp4

# %%
# Program To Read video
# and Extract Frames
import cv2
  
# Function to extract frames
def FrameCapture(path):
      
    # Path to video file
    vidObj = cv2.VideoCapture(path)
  
    # Used as counter variable
    count = 0
  
    # checks whether frames were extracted
    success = 1
  
    while success:
  
        # vidObj object calls read
        # function extract frames
        success, image = vidObj.read()
  
        # Saves the frames with frame-count
        try : 
          cv2.imwrite("frame%d.jpg" % count, image)
        except :
          pass 
        count += 1
  
# Driver Code

# %%
FrameCapture("/content/gdrive/My Drive/Projects /RL_Driving/Front_view/final_60ae52e07c16e9007c4ca144_50027.mp4")

# %%
ls

# %%
# %%bash
# pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5m', pretrained=True)

# Images
dir = '/content/gdrive/My Drive/Projects /RL_Driving/Front_view/'
imgs = [dir + f for f in ('frame340.jpg', 'frame668.jpg',"x.png")]  # batched list of images

# Inference
results = model(imgs)

# Results
results.print()  
results.save()  # or .show()

# Data
print(results.xyxy[0])  # print img1 predictions (pixels)
#                   x1           y1           x2           y2   confidence        class
# tensor([[7.50637e+02, 4.37279e+01, 1.15887e+03, 7.08682e+02, 8.18137e-01, 0.00000e+00],
#         [9.33597e+01, 2.07387e+02, 1.04737e+03, 7.10224e+02, 5.78011e-01, 0.00000e+00],
#         [4.24503e+02, 4.29092e+02, 5.16300e+02, 7.16425e+02, 5.68713e-01, 2.70000e+01]])
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Fusing layers...
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...
# YOLOv5 🚀 2021-5-26 torch 1.8.1+cu101 CPU
# image 1/3: 720x1280 3 persons, 4 cars, 1 bus, 1 truck, 3 traffic lights
# image 2/3: 720x1280 7 persons, 4 cars, 1 truck, 3 traffic lights
# image 3/3: 756x608 2 persons, 1 chair
# Speed: 24.3ms pre-process, 550.7ms inference, 1.7ms NMS per image at shape (3, 3, 640, 640)
# Saved frame340.jpg, frame668.jpg, x.jpg to runs/hub/exp3
# tensor([[9.67860e+02, 5.03887e+02, 1.27898e+03, 7.12816e+02, 9.14256e-01, 2.00000e+00],
# ...

# %%
class_labels[5]
# Out:
# 'bus'

# %%
vars(results)
# Out:
# {'files': ['tk.jpg'], 'imgs': [array([[[127, 143, 158],
#           [124, 140, 155],
#           [128, 144, 159],
#           ...,
#           [ 71,  88,  95],
#           [ 81,  98, 105],
#           [ 88, 107, 113]],
#
#          [[121, 137, 152],
#           [137, 153, 168],
#           [132, 148, 163],
#           ...,
#           [131, 148, 155],
#           [115, 132, 139],
#           [121, 138, 145]],
#
#          [[126, 142, 157],
#           [125, 141, 156],
#           [128, 144, 159],
#           ...,
#           [123, 140, 147],
#           [126, 143, 150],
#           [130, 147, 154]],
#
#          ...,
#
#          [[ 53,  58,  64],
#           [ 47,  52,  58],
#           [ 41,  46,  52],
#           ...,
#           [ 87, 103, 118],
#           [ 86, 102, 117],
#           [ 86, 102, 117]],
#
#          [[ 71,  76,  82],
#           [ 64,  69,  75],
#           [ 53,  58,  64],
#           ...,
#           [ 87, 103, 118],
#           [ 85, 101, 116],
# ...

# %%
from matplotlib.image import imread
# %matplotlib inline
rand_img = imread("x.png")
label="ThunderBoom"
cv2.putText(rand_img, label, (200, 100));
plt.imshow(rand_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-6f7c5501fe08> in <module>()
#       3 rand_img = imread("x.png")
#       4 label="ThunderBoom"
# ----> 5 cv2.putText(rand_img, label, (200, 100));
#       6 plt.imshow(rand_img)
#
# TypeError: putText() missing required argument 'fontFace' (pos 4)

# %%
def add_text_label(text,position,img):
  print("text=>",text)
  text=str(text)
  
  font = cv2.FONT_HERSHEY_SIMPLEX
  org = position
  fontScale = 1
  color = (0, 255, 255)
  thickness = 2
  img = cv2.putText(img, text, org, font, fontScale, 
                  color, thickness, cv2.LINE_AA, False)
    
  return img

# %%
text = "ThunderBoom"
  
# font
font = cv2.FONT_HERSHEY_SIMPLEX
org = (200, 100)
# fontScale
fontScale = 1
# Red color in BGR
color = (0, 255, 255)
# Line thickness of 2 px
thickness = 2
# Using cv2.putText() method
rand_img = cv2.putText(rand_img, text, org, font, fontScale, 
                 color, thickness, cv2.LINE_AA, False)

# %%
plt.imshow(rand_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x=150
y=170
w=300
h=450

x_image=cv2.rectangle(rand_img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(rand_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model_type='yolov5x'
model = torch.hub.load('ultralytics/yolov5',model_type , pretrained=True)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# Adding AutoShape...
# YOLOv5 🚀 2021-5-26 torch 1.8.1+cu101 CPU

# %%
dir = '/content/gdrive/My Drive/Projects /RL_Driving/Front_view/'
imgs = [dir +'tk.jpg']  # batched list of images
rand_img = imread(imgs[0])
img=rand_img
# Inference
results = model(imgs)
class_labels=results.names
rect_tensor=results.xyxy[0]
for rect in rect_tensor:
  x1=int(rect[0])
  y1=int(rect[1])
  x2=int(rect[2])
  y2=int(rect[3])
  class_id=int(rect[5])
  text=class_labels[class_id]
  #print(x1,x2,y1,y2)

  img=cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)
  #text="class name"
  xav=int((x1+x2)/2)
  yav=int((y1+y2)/2)
  position=(xav,yav)
  img=add_text_label(text,position,img)
plt.imshow(img)
# Out:
# text=> car
# text=> car
# text=> car
# text=> car
# text=> person
# text=> person
# text=> car
# text=> person
# text=> person
# text=> motorcycle
# text=> person
# text=> traffic light
# text=> person
# text=> car
# text=> person
# text=> person
# text=> person
# text=> car
# text=> person
# text=> person
# text=> traffic light
# text=> traffic light
# text=> car
# text=> traffic light
# text=> person

# %%
results.print()
# Out:
# image 1/1: 905x1898 12 persons, 8 cars, 1 motorcycle, 4 traffic lights
# Speed: 37.2ms pre-process, 2386.2ms inference, 1.1ms NMS per image at shape (1, 3, 320, 640)

# %%
image_path='/content/gdrive/My Drive/Projects /RL_Driving/rlabe.jpg'
cv2.imwrite(image_path,img)
# Out:
# True

# %%
#yolo5m 11 persons, 8 cars, 1 motorcycle, 1 truck, 7 traffic lights
#yolo5l 11 persons, 8 cars, 1 motorcycle, 1 truck, 6 traffic lights
#yolo5x 12 persons, 8 cars, 1 motorcycle, 4 traffic lights
